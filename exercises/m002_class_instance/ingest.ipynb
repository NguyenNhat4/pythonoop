# %%
init_schema()
# Out:
# 2025-11-22 21:33:53,142 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-11-22 21:33:53,142 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-22 21:33:53,146 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-11-22 21:33:53,147 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-22 21:33:53,150 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-11-22 21:33:53,151 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-22 21:33:53,159 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-22 21:33:53,160 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# ...

# %%
get_list_productTypes()
# Out:
# 2025-11-22 21:34:20,772 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-22 21:34:20,773 INFO sqlalchemy.engine.Engine SELECT product_types.id, product_types.name
# FROM product_types
# 2025-11-22 21:34:20,773 INFO sqlalchemy.engine.Engine [cached since 24.64s ago] {}
# 2025-11-22 21:34:20,776 INFO sqlalchemy.engine.Engine ROLLBACK
# []
