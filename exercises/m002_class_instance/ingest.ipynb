# %%
from crud import *

# %%
init_schema()
# Out:
# 2025-11-22 21:41:57,170 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-22 21:41:57,172 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s::VARCHAR AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s::VARCHAR, %(param_2)s::VARCHAR, %(param_3)s::VARCHAR, %(param_4)s::VARCHAR, %(param_5)s::VARCHAR]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s::VARCHAR
# 2025-11-22 21:41:57,172 INFO sqlalchemy.engine.Engine [cached since 1428s ago] {'table_name': 'products', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-11-22 21:41:57,283 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s::VARCHAR AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s::VARCHAR, %(param_2)s::VARCHAR, %(param_3)s::VARCHAR, %(param_4)s::VARCHAR, %(param_5)s::VARCHAR]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s::VARCHAR
# 2025-11-22 21:41:57,284 INFO sqlalchemy.engine.Engine [cached since 1428s ago] {'table_name': 'product_types', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-11-22 21:41:57,286 INFO sqlalchemy.engine.Engine COMMIT

# %%
get_list_productTypes()
# Out:
# 2025-11-22 21:41:58,993 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-22 21:41:58,994 INFO sqlalchemy.engine.Engine SELECT product_types.id, product_types.name
# FROM product_types
# 2025-11-22 21:41:58,995 INFO sqlalchemy.engine.Engine [cached since 1629s ago] {}
# 2025-11-22 21:41:59,012 INFO sqlalchemy.engine.Engine SELECT products.type_id AS products_type_id, products.id AS products_id, products.name AS products_name, products.price AS products_price, products.quantity AS products_quantity
# FROM products
# WHERE products.type_id IN (%(primary_keys_1)s::INTEGER, %(primary_keys_2)s::INTEGER, %(primary_keys_3)s::INTEGER, %(primary_keys_4)s::INTEGER, %(primary_keys_5)s::INTEGER)
# 2025-11-22 21:41:59,013 INFO sqlalchemy.engine.Engine [cached since 1629s ago] {'primary_keys_1': 1, 'primary_keys_2': 2, 'primary_keys_3': 3, 'primary_keys_4': 4, 'primary_keys_5': 5}
# 2025-11-22 21:41:59,020 INFO sqlalchemy.engine.Engine ROLLBACK
# [Product(id=1) ,  name='VEGETABLES'),
#  Product(id=2) ,  name='FRUITS'),
#  Product(id=3) ,  name='GRAINS_LEGUMES'),
#  Product(id=4) ,  name='DAIRY_EGGS'),
#  Product(id=5) ,  name='MEAT_SEAFOOD')]

# %%
def clean_one_row(one_line):
    one_line = one_line.split()
    clean_row = []
    name = ""
    for element in one_line:
        if element.isnumeric():
            clean_row.append(int(element))
        else:
            name = name + " "  + element
            
    name = name.strip()
    clean_row.insert(1, name)
    return clean_row

# %%
with open("orderitems.txt","r") as f:
    lines = f.readlines()

# %%
clean_lines = [clean_one_row(i) for i in lines[1:]]

# %%
first_product = clean_lines[1]
first_product
# Out:
# [2, 'Garlic', 3000, 200]

# %%
productid_and_typeid =

# %%
list_Product = [
     Product(id=element[0],name=element[1],price=element[2],quantity=element[3],type_id=3)
    
 ]

# %%
def insert_one_product(p : Product):
    with Session(engine) as session:
        session.add(p)
        
        session.commit()

# %%
insert_one_product(p)
# Out:
# 2025-11-22 22:09:57,143 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-22 22:09:57,143 INFO sqlalchemy.engine.Engine INSERT INTO products (id, name, price, quantity, type_id) VALUES (%(id)s::INTEGER, %(name)s::VARCHAR, %(price)s::INTEGER, %(quantity)s::INTEGER, %(type_id)s::INTEGER)
# 2025-11-22 22:09:57,144 INFO sqlalchemy.engine.Engine [cached since 21.21s ago] {'id': 2, 'name': 'Garlic', 'price': 3000, 'quantity': 200, 'type_id': 3}
# 2025-11-22 22:09:57,156 INFO sqlalchemy.engine.Engine COMMIT

# %%
insert_list_products()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 insert_list_products()
#
# NameError: name 'insert_list_products' is not defined
